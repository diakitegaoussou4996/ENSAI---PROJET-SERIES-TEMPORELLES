# %% [markdown]
# <br>
# <img src="https://th.bing.com/th/id/R.08d78d547107a48d03c6eb2f5141f09b?rik=KNbP59PpBQwWWQ&riu=http%3a%2f%2fensai.fr%2fwp-content%2fuploads%2f2019%2f05%2fEnsai-logo-300x282.png&ehk=aRCY7kpUQ083sCCZKjkAqzG8uUQFRF8IV%2b19WNjLSwQ%3d&risl=&pid=ImgRaw&r=0&sres=1&sresct=1" width=90px align="left">
# <div align="right" style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <strong>Enseignant :</strong> ESSTAFA Youssef
# </div>
# <div align="right" style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <strong>Réalisé par :</strong> DIAKITE Gaoussou
# </div>
# <div align="right" style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <strong>Année :</strong> 2023/2024
# </div><br><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:32px;color:#4CAF50">MASTÈRE DATA SCIENCE - CONNAISSANCE CLIENT</span></div><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:28px;color:#4CAF50">Prévision de la Consommation Énergétique en France</span></div><br><br>
# <hr>

# %% [markdown]
# <br>
# <img src="https://www.greensystemes.com/wp-content/uploads/2020/07/optimiser-la-consommation-energetique-de-son-entreprise-grace-a-lenergie-verte.jpg" width=90px align="left">
#
# <hr style="border-width:4px;border-color:#4CAF50">
# <center><h1>Prévision de la Consommation Énergétique en France</h1></center>
# <hr style="border-width:4px;border-color:#4CAF50">
#
# >Dans un contexte de plus en plus axé sur la durabilité et l'efficacité énergétique, la prévision précise de la consommation énergétique devient un enjeu majeur. Avec l'évolution constante des technologies et des comportements des consommateurs, les fournisseurs d'énergie et les gouvernements doivent adapter leurs stratégies pour répondre efficacement à la demande tout en minimisant les impacts environnementaux.
#
# >Cette étude vise à analyser les tendances de consommation énergétique en France en utilisant des données historiques. Elle offre une opportunité unique d'explorer comment les facteurs externes tels que la température influencent la consommation d'énergie et comment les modèles prédictifs peuvent être utilisés pour anticiper les besoins futurs.
#
# >
# ><h2 style="color:#4CAF50; font-family: 'Arial', sans-serif;">🔍 Contexte et Pertinence du Projet</h2>
# >
# > Dans ce projet, nous abordons le défi de prédire la consommation énergétique quotidienne en France. En utilisant des données historiques, nous cherchons à identifier les modèles et les tendances qui influencent la demande en énergie. Cette analyse nous permettra de proposer des solutions pour une meilleure gestion de l'énergie, en tenant compte des variations saisonnières et des événements imprévus.
#
# >En outre, cette étude contribuera à mieux comprendre l'impact des variables environnementales sur la consommation d'énergie, permettant ainsi aux fournisseurs et aux régulateurs d'optimiser leurs stratégies de distribution et de production.
#
# >
# ><h2 style="color:#4CAF50; font-family: 'Arial', sans-serif;">🎯 Objectifs Clés du Projet</h2>
# >
# >1. **Exploration des Données :** Examiner les tendances historiques de la consommation d'énergie et identifier les facteurs clés qui influencent ces tendances.
#
# >2. **Prétraitement des Données :** Nettoyer et préparer les données pour l'analyse, en créant des indicateurs pertinents qui peuvent améliorer la précision des prévisions.
#
# >3. **Modélisation Prédictive :** Développer et entraîner des modèles de machine learning pour prédire la consommation d'énergie future en France.
#
# >4. **Évaluation et Optimisation du Modèle :** Tester la précision des modèles et les ajuster pour améliorer leur fiabilité et leur applicabilité.
#
# >
# ><h2 style="color:#4CAF50; font-family: 'Arial', sans-serif;">💡 Utilité et Impact du Projet</h2>
# >
# >Cette étude apporte une contribution significative dans le domaine de la gestion de l'énergie. En anticipant la demande énergétique, les fournisseurs peuvent optimiser la production et la distribution, réduisant ainsi les coûts et l'impact environnemental. De plus, ces prévisions peuvent aider à la prise de décisions stratégiques dans la planification énergétique nationale, contribuant à un avenir plus durable et efficace sur le plan énergétique.
# >
# <br/><br/><br/>

# %% [markdown]
# <br/>
# <hr style="border-width:4px;border-color:#4CAF50">
# <center><h1>Présentation de la Base de Données Énergétique</h1></center>
# <hr style="border-width:4px;border-color:#4CAF50">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette section, nous présentons les variables de la base de données utilisée pour notre analyse sur la consommation énergétique en France, couvrant la période de 2020 à 2023. Les données incluent des informations détaillées sur la consommation d'énergie, les températures moyennes, et d'autres mesures pertinentes. Les sources des données sont disponibles aux liens suivants :
#     <ul>
#         <li><a href="https://odre.opendatasoft.com/explore/dataset/pic-journalier-consommation-brute/export/" target="_blank">Pic Journalier de Consommation Brute</a></li>
#         <li><a href="https://odre.opendatasoft.com/explore/dataset/consommation-quotidienne-corrige-brute/information/" target="_blank">Consommation Quotidienne Corrigée Brute</a></li>
#         <li><a href="https://analysesetdonnees.rte-france.com/consommation/synthese" target="_blank">Synthèse de la Consommation Brute</a></li>
#     </ul>
# </p>
# <ul style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Date :</strong> La date de l'enregistrement.</li>
#     <li><strong>Pic Journalier Consommation (MW) :</strong> Pic de consommation d'énergie journalier en mégawatts.</li>
#     <li><strong>Température Moyenne (°C) :</strong> Température moyenne en degrés Celsius.</li>
#     <li><strong>Température Référence (°C) :</strong> Température de référence en degrés Celsius.</li>
#     <li><strong>Consommation à Température Normale (MW) :</strong> Consommation d'énergie ajustée à une température normale.</li>
#     <li><strong>Consommation Brute (MW) :</strong> Consommation brute d'énergie en mégawatts.</li>
# </ul>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Importation des bibliothèques importantes</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.impute import SimpleImputer
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy.signal import find_peaks
from statsmodels.tsa.stattools import adfuller, kpss
from arch.unitroot import PhillipsPerron
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.ar_model import AutoReg
from pmdarima import auto_arima
import plotly.express as px


from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, make_scorer
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np




import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Importation des des données</h1>

# %%
df_conso_corr = pd.read_excel("Data/consommation-quotidienne-corrige-brute.xlsx")
df_conso_brut = pd.read_csv("Data/dl_graph_2282_fr.csv", delimiter=";")
df_pic_conso = pd.read_excel("Data/pic-journalier-consommation-brute.xlsx")

# %%
df_conso_corr.head()
# Out:
#          date  Consommation à température normale (MW)
# 0  2014-01-01                                    60955
# 1  2014-01-02                                    67923
# 2  2014-01-03                                    70153
# 3  2014-01-04                                    66541
# 4  2014-01-05                                    64399

# %%
df_conso_brut.head()
# Out:
#          Date                      Filière  Valeur (GW)
# 0  01/01/2019  Enveloppe basse 2014 - 2019  53,90419485
# 1  02/01/2019  Enveloppe basse 2014 - 2019  64,63343265
# 2  03/01/2019  Enveloppe basse 2014 - 2019  64,12361827
# 3  04/01/2019  Enveloppe basse 2014 - 2019  63,32177608
# 4  05/01/2019  Enveloppe basse 2014 - 2019  67,94584104

# %%
df_pic_conso.head()
# Out:
#          Date  Pic journalier consommation (MW)  Température moyenne (°C)  \
# 0  2012-01-01                             59610                      11.7
# 1  2012-01-04                             78337                       8.1
# 2  2012-01-13                             78700                       5.3
# 3  2012-01-14                             74666                       2.4
# 4  2012-01-19                             80026                       8.4
#
#    Température référence (°C)
# 0                         4.6
# 1                         4.6
# 2                         4.8
# 3                         4.8
# 4                         5.0

# %% [markdown]
# <br/>
# <hr style="border-width:4px;border-color:#4CAF50">
# <center><h1>Traitement des données</h1></center>
# <hr style="border-width:4px;border-color:#4CAF50">

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Traitement des données</h1>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Préparation de la Base de Données</span>
# <p style="font-size: 16px;">
#     Dans cette première phase, l'objectif est d'ajuster et de standardiser la base de données sur la consommation d'énergie brute moyenne journalière. Cela implique de mettre à jour le format des colonnes pour une meilleure lisibilité et uniformité, de renommer les variables pour faciliter leur compréhension, et de convertir les valeurs en mégawatts (MW) pour assurer la compatibilité avec les autres jeux de données. En outre, je filtrerai la colonne 'Filière' pour ne retenir que les informations essentielles liées à la consommation brute.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Conversion et Jointure des Bases de Données</span>
# <p style="font-size: 16px;">
#     La prochaine étape consiste à convertir les colonnes de dates dans toutes les bases de données au format datetime, permettant ainsi une intégration harmonieuse. La jointure de ces ensembles de données sera réalisée en alignant les informations sur les dates correspondantes, avec pour objectif de créer un seul et unique ensemble de données complet. Cette jointure se focalisera sur la conservation des informations communes à tous les jeux de données, formant ainsi une base consolidée pour les analyses futures.
# </p>

# %%
# vérifications des types de mes bases de données
print(df_conso_corr.dtypes)
print("___________________________________________________________")
print(df_conso_brut.dtypes)
print("___________________________________________________________")
print(df_pic_conso.dtypes)
# Out:
# date                                       object
# Consommation à température normale (MW)     int64
# dtype: object
# ___________________________________________________________
# Date           object
# Filière        object
# Valeur (GW)    object
# dtype: object
# ___________________________________________________________
# Date                                 object
# Pic journalier consommation (MW)      int64
# Température moyenne (°C)            float64
# Température référence (°C)          float64
# dtype: object

# %%
# Remplacer les virgules par des points et convertir en numérique
df_conso_brut['Consommation Brut (MW)'] = pd.to_numeric(df_conso_brut['Valeur (GW)'].str.replace(',', '.'), errors='coerce') * 1000
# Arrondir la colonne 'Consommation Brut (MW) ' et convertir en entiers
df_conso_brut['Consommation Brut (MW)'] = df_conso_brut['Consommation Brut (MW)'].round(0)

# Filtrer les données pour conserver uniquement les lignes avec "Consommation brute" et supprimer la colonne "Filière"
df_conso_brut = df_conso_brut[df_conso_brut["Filière"] == "Consommation brute"].drop(['Filière', 'Valeur (GW)'], axis=1)
df_conso_brut = df_conso_brut.groupby('Date').mean().reset_index()
df_conso_brut.head()
# Out:
#          Date  Consommation Brut (MW)
# 0  01/01/2020                 63465.5
# 1  01/01/2021                 56792.0
# 2  01/01/2022                 52116.5
# 3  01/01/2023                     NaN
# 4  01/02/2020                 70417.0

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #4CAF50; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Conversion des Dates en Format DateTime</h3>
# </div>

# %%
# je renomme la variable date en Date
df_conso_corr  = df_conso_corr.rename(columns={"date": "Date"})

# Je convertis les dates
df_conso_corr['Date'] = pd.to_datetime(df_conso_corr['Date'])
df_pic_conso['Date'] = pd.to_datetime(df_pic_conso['Date'])
df_conso_brut['Date'] = pd.to_datetime(df_conso_brut['Date'], format='%d/%m/%Y')

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #4CAF50; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Jointure des Bases de Données sur les Dates Communes</h3>
# </div>

# %%
# Fusion des deux premiers DataFrames
df_joined_temp = pd.merge(df_pic_conso, df_conso_corr, on='Date', how='inner')
# Fusion du DataFrame intermédiaire avec le troisième DataFrame
Conso_Energie = pd.merge(df_joined_temp, df_conso_brut, on='Date', how='inner')

# %%
Conso_Energie.head()
# Out:
#         Date  Pic journalier consommation (MW)  Température moyenne (°C)  \
# 0 2021-01-02                             74934                       1.5
# 1 2021-01-04                             85625                       1.8
# 2 2021-01-05                             86311                       1.9
# 3 2021-01-16                             78993                       1.6
# 4 2021-01-20                             76855                       8.8
#
#    Température référence (°C)  Consommation à température normale (MW)  \
# 0                         4.6                                    63544
# 1                         4.6                                    70596
# 2                         4.6                                    72723
# 3                         4.9                                    67011
# 4                         5.0                                    72693
#
#    Consommation Brut (MW)
# 0                 74590.0
# 1                 77062.5
# ...

# %%
#Conso_Energie.to_excel("Data/Conso_Energie.xlsx")

# %%
# Taille du jeu de données
print(f'La base de donne fait {Conso_Energie.shape[0]} lignes et {Conso_Energie.shape[1]} après la jointure ')
# Out:
# La base de donne fait 1430 lignes et 6 après la jointure

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Vérification Visuelle des Valeurs Manquantes</h3>
#     <p>
#         Nous avons créé une carte de chaleur pour visualiser les valeurs manquantes dans notre base de données. Cette méthode permet d'identifier rapidement les colonnes et les rangées qui contiennent des données incomplètes. Les zones jaunes sur la carte représentent les valeurs manquantes, nous aidant à comprendre l'étendue et la distribution des données manquantes dans l'ensemble de données.
#     </p>
# </div>

# %%
# Vérification visuelle des valeurs manquantes
plt.figure(figsize=(8, 4))
sns.heatmap(Conso_Energie.isnull(), cbar=False, cmap='viridis')
plt.title('Carte de Chaleur des Valeurs Manquantes')
plt.xlabel('Colonnes')
plt.ylabel('Index des Entrées')
plt.show()

# %%
nombre_valeurs_manquantes_conso_brut = Conso_Energie['Consommation Brut (MW)'].isna().sum()
print(f'Le nombre de valeur manquante dans la colonne Consommation Brut est de {nombre_valeurs_manquantes_conso_brut}')
# Out:
# Le nombre de valeur manquante dans la colonne Consommation Brut est de 37

# %%
Stat_Conso_Brut = Conso_Energie['Consommation Brut (MW)'].describe().to_frame().T
Stat_Conso_Brut
# Out:
#                          count          mean           std      min      25%  \
# Consommation Brut (MW)  1393.0  51667.233309  10386.460078  35288.0  43868.0
#
#                             50%      75%      max
# Consommation Brut (MW)  47554.5  60611.5  77591.0

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Imputation des valeurs manquantes pour 'Consommation Brut (MW)'</h3>
#     <p>
#         Après avoir identifié les valeurs manquantes à l'aide d'une carte de chaleur, nous avons constaté que la colonne 'Consommation Brut (MW)' nécessitait une attention particulière pour l'imputation. Cette visualisation a été essentielle pour comprendre la portée et la répartition des données manquantes.
#     </p>
#     <p>
#         L'analyse statistique descriptive de la variable 'Consommation Brut (MW)' après le traitement des doublons donne les résultats suivants :
#     </p>
#     <ul>
#         <li>Nombre total d'observations (count) : 1393</li>
#         <li>Moyenne (mean) : 51667.23 MW</li>
#         <li>Écart-type (std) : 10386.46 MW</li>
#         <li>Valeur minimale (min) : 35288 MW</li>
#         <li>1er quartile (25%) : 43868 MW</li>
#         <li>Médiane (50%) : 47554.5 MW</li>
#         <li>3ème quartile (75%) : 60611.5 MW</li>
#         <li>Valeur maximale (max) : 77591 MW</li>
#     </ul>
#     <p>
#         Compte tenu de cette distribution, nous avons choisi d'utiliser la <strong>médiane</strong> pour l'imputation des valeurs manquantes. Ce choix est motivé par le fait que la médiane est moins influencée par les valeurs aberrantes en comparaison de la moyenne. L'écart-type relativement élevé (10386.46 MW) indique la présence de valeurs extrêmes, qui pourraient fausser la moyenne. En utilisant la médiane de 47554.5 MW comme valeur d'imputation, nous assurons une estimation plus fiable et représentative de la tendance centrale pour la variable 'Consommation Brut (MW)'.
#     </p>
#     <p>
#         L'approche d'imputation par la médiane permet de maintenir la distribution générale des données tout en comblant efficacement les lacunes, ce qui facilite des analyses ultérieures plus précises et fiables.
#     </p>
# </div>

# %%
# Calculer la médiane de la colonne 'Consommation Brut (MW)'
median_value = Conso_Energie['Consommation Brut (MW)'].median()

# Remplacer les valeurs manquantes par la médiane
Conso_Energie['Consommation Brut (MW)'].fillna(median_value, inplace=True)

# Vérifier si l'imputation a réussi
nombre_valeurs_manquantes_apres_imputation = Conso_Energie['Consommation Brut (MW)'].isna().sum()
print("Nombre de valeurs manquantes après imputation :", nombre_valeurs_manquantes_apres_imputation)
# Out:
# Nombre de valeurs manquantes après imputation : 0

# %% [markdown]
# <br/>
# <hr style="border-width:4px;border-color:#4CAF50">
# <center><h1>Ingénierie des Caractéristiques</h1></center>
# <hr style="border-width:4px;border-color:#4CAF50">

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Ingénierie des Caractéristiques</h1>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Extraction des Caractéristiques Temporelles</span>
# <p style="font-size: 16px;">
#     Notre analyse commence par l'extraction minutieuse des composants temporels des données. En définissant la date comme index de notre DataFrame, nous avons pu extraire des informations clés telles que l'année, le mois, le jour, le jour de la semaine et le numéro de la semaine. Cette étape est cruciale pour comprendre les tendances et les cycles saisonniers affectant la consommation d'énergie.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Identification des Jours Fériés</span>
# <p style="font-size: 16px;">
#     Une innovation de notre analyse est l'intégration des jours fériés dans le modèle. En identifiant les jours fériés de 2020 à 2023, nous avons créé une variable binaire 'IsHoliday' pour marquer ces dates spécifiques. Cela nous permet de prendre en compte les variations exceptionnelles de consommation d'énergie pendant ces jours.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Ajout de Caractéristiques Complémentaires</span>
# <p style="font-size: 16px;">
#     Au-delà des composantes temporelles et des jours fériés, nous avons enrichi nos données avec des caractéristiques supplémentaires pour une analyse plus approfondie. Cela inclut la transformation des jours de la semaine en noms explicites et l'ajout d'indicateurs pour les week-ends. Ces ajouts contribuent à une meilleure compréhension des habitudes de consommation d'énergie.
# </p>
#
# <p style="font-size: 16px;">
#     Ensemble, ces étapes d'ingénierie des caractéristiques renforcent notre modèle prédictif, nous permettant d'aborder la prédiction de la consommation énergétique avec une perspective plus holistique et détaillée.
# </p>

# %%
Conso_Energie=Conso_Energie.sort_values(by="Date")
Conso_Energie.head()
# Out:
#           Date  Pic journalier consommation (MW)  Température moyenne (°C)  \
# 284 2020-01-01                             66221                       4.0
# 285 2020-01-02                             72399                       6.1
# 142 2020-01-03                             69650                       8.3
# 524 2020-01-04                             67013                       6.7
# 147 2020-01-05                             68154                       5.8
#
#      Température référence (°C)  Consommation à température normale (MW)  \
# 284                         4.6                                    60767
# 285                         4.6                                    66879
# 142                         4.6                                    68430
# 524                         4.6                                    66059
# 147                         4.6                                    64850
#
#      Consommation Brut (MW)
# 284                 63465.5
# ...

# %%
# Liste des jours fériés en France de 2020 à 2023
holidays = pd.to_datetime([
    "2020-01-01", "2020-04-13", "2020-05-01", "2020-05-08", "2020-05-21", 
    "2020-06-01", "2020-07-14", "2020-08-15", "2020-11-01", "2020-11-11", "2020-12-25",
    "2021-01-01", "2021-04-05", "2021-05-01", "2021-05-08", "2021-05-13", 
    "2021-05-24", "2021-07-14", "2021-08-15", "2021-11-01", "2021-11-11", "2021-12-25",
    "2022-01-01", "2022-04-18", "2022-05-01", "2022-05-08", "2022-05-26", 
    "2022-06-06", "2022-07-14", "2022-08-15", "2022-11-01", "2022-11-11", "2022-12-25",
    "2023-01-01", "2023-04-10", "2023-05-01", "2023-05-08", "2023-05-18", 
    "2023-05-29", "2023-07-14", "2023-08-15", "2023-11-01", "2023-11-11", "2023-12-25",
])

# Créer la colonne 'IsHoliday' basée sur la colonne 'Date'
Conso_Energie['IsHoliday'] = Conso_Energie['Date'].isin(holidays).astype(int)

Conso_Energie['Date'] = pd.to_datetime(Conso_Energie['Date'])

# Mettre la colonne 'Date' comme index
Conso_Energie.set_index('Date', inplace=True)

# Extraction des caractéristiques temporelles
Conso_Energie['Year'] = Conso_Energie.index.year # Année : Numérique, l'année extraite de la date.
Conso_Energie['Month'] = Conso_Energie.index.month # Mois : Numérique, le mois extrait de la date, de 1 (janvier) à 12 (décembre).
Conso_Energie['Day'] = Conso_Energie.index.day # Jour : Numérique, le jour du mois extrait de la date, de 1 à 31.
Conso_Energie['Weekday'] = Conso_Energie.index.weekday # Jour de la semaine : Numérique, le jour de la semaine extrait de la date, de 0 (lundi) à 6 (dimanche).
Conso_Energie['WeekOfYear'] = Conso_Energie.index.isocalendar().week # Semaine de l'année : Numérique, le numéro de la semaine de l'année, selon la norme ISO.
Conso_Energie['DayOfWeek'] = Conso_Energie.index.dayofweek # Jour de la semaine (bis) : Numérique, le jour de la semaine de 0 (lundi) à 6 (dimanche), similaire à 'Weekday'.
Conso_Energie['IsWeekend'] = Conso_Energie['DayOfWeek'].isin([5, 6]).astype(int) # Week-end : Binaire, indique si la date est un samedi (5) ou un dimanche (6), avec 1 pour oui et 0 pour non.


days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# Ajouter une colonne avec le nom du jour de la semaine
Conso_Energie['Weekday Name'] = Conso_Energie['Weekday'].apply(lambda x: days[x])
Conso_Energie.head()
# Out:
#             Pic journalier consommation (MW)  Température moyenne (°C)  \
# Date
# 2020-01-01                             66221                       4.0
# 2020-01-02                             72399                       6.1
# 2020-01-03                             69650                       8.3
# 2020-01-04                             67013                       6.7
# 2020-01-05                             68154                       5.8
#
#             Température référence (°C)  \
# Date
# 2020-01-01                         4.6
# 2020-01-02                         4.6
# 2020-01-03                         4.6
# 2020-01-04                         4.6
# 2020-01-05                         4.6
#
#             Consommation à température normale (MW)  Consommation Brut (MW)  \
# Date
# 2020-01-01                                    60767                 63465.5
# 2020-01-02                                    66879                 71354.5
# ...

# %% [markdown]
# <br/>
# <hr style="border-width:4px;border-color:#4CAF50">
# <center><h1>Analyse Exploratoire des Données (AED)</h1></center>
# <hr style="border-width:4px;border-color:#4CAF50">

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">
#     Analyse Exploratoire des Données (AED)
# </h1>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Découverte et Compréhension des Données
# </span>
# <p style="font-size: 16px;">
#     L'objectif de cette phase est d'examiner attentivement nos données sur la consommation énergétique. Nous commençons par observer les tendances générales, les variations saisonnières, et les anomalies. Cette étape est fondamentale pour comprendre comment les différents facteurs comme le temps et les conditions météorologiques influencent la consommation d'énergie.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Identification des Modèles et des Corrélations
# </span>
# <p style="font-size: 16px;">
#     Au cours de l'analyse, nous chercherons à identifier des modèles récurrents et à comprendre les corrélations entre différentes variables. Par exemple, comment la température affecte-t-elle la consommation d'énergie ? Y a-t-il des jours de la semaine ou des mois où la consommation est systématiquement plus élevée ? Cette compréhension nous aidera à prévoir les besoins futurs en énergie et à optimiser les stratégies de gestion de l'énergie.
# </p>

# %%
# Création des graphiques dans une figure unique
plt.figure(figsize=(12, 16))

# Graphique pour 'Consommation Brut (MW)'
plt.subplot(4, 1, 1)
sns.lineplot(data=Conso_Energie, x=Conso_Energie.index, y='Consommation Brut (MW)', color='blue')
plt.title('Tendance de la Consommation Énergétique Brut')
plt.ylabel('Consommation Brut (MW)')
plt.grid(True)

# Graphique pour 'Consommation à température normale (MW)'
plt.subplot(4, 1, 2)
sns.lineplot(data=Conso_Energie, x=Conso_Energie.index, y='Consommation à température normale (MW)', color='green')
plt.title('Consommation Énergétique à Température Normale')
plt.ylabel('Consommation à température normale (MW)')
plt.grid(True)

# Graphique pour 'Pic journalier consommation (MW)'
plt.subplot(4, 1, 3)
sns.lineplot(data=Conso_Energie, x=Conso_Energie.index, y='Pic journalier consommation (MW)', color='red')
plt.title('Pic Journalier de Consommation Énergétique')
plt.ylabel('Pic journalier consommation (MW)')
plt.grid(True)

# Graphique pour 'Température moyenne (°C)'
plt.subplot(4, 1, 4)
sns.lineplot(data=Conso_Energie, x=Conso_Energie.index, y='Température moyenne (°C)', color='purple')
plt.title('Tendance de la Température Moyenne')
plt.ylabel('Température moyenne (°C)')
plt.xlabel('Date')
plt.grid(True)

# Ajuster l'espace entre les graphiques
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Commentaire sur la Visualisation des Données Énergétiques</h3>
#     <p>
#         Les graphiques présentés illustrent les tendances des différentes mesures de consommation énergétique sur une période donnée. Le premier graphique, en bleu, démontre la consommation énergétique brute, affichant des pics qui pourraient coïncider avec des périodes de forte demande ou des événements saisonniers. Le second, en vert, montre la consommation énergétique ajustée à une température normale, permettant d'observer l'effet des variations climatiques sur la consommation d'énergie. Le troisième graphique, en rouge, indique le pic journalier de consommation énergétique, soulignant les jours avec la plus haute demande. Enfin, le graphique en violet trace la tendance de la température moyenne, fournissant un contexte pour les variations de consommation observées. Ensemble, ces visualisations offrent une vue complète et détaillée du comportement énergétique, essentielle pour la planification et l'optimisation des ressources énergétiques.
#     </p>
# </div>

# %%
# Calcul de la corrélation entre la température et la consommation d'énergie
correlation_matrix = Conso_Energie[['Consommation Brut (MW)', 'Température moyenne (°C)']].corr()

# Tendances de consommation par jour de la semaine et par mois
#df['Weekday'] = df.index.weekday
#df['Month'] = df.index.month
weekly_trends = Conso_Energie.groupby('Weekday')['Consommation Brut (MW)'].mean()
monthly_trends = Conso_Energie.groupby('Month')['Consommation Brut (MW)'].mean()

# Création des graphiques
plt.figure(figsize=(14, 12))

# Corrélation entre température et consommation
plt.subplot(2, 2, 1)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Corrélation entre Température et Consommation')

# Consommation moyenne par jour de la semaine
plt.subplot(2, 2, 2)
weekly_trends.plot(kind='bar')
plt.title('Consommation Moyenne par Jour de la Semaine')
plt.xlabel('Jour de la semaine')
plt.ylabel('Consommation Moyenne (MW)')

# Consommation moyenne par mois
plt.subplot(2, 2, 3)
monthly_trends.plot(kind='bar', color='green')
plt.title('Consommation Moyenne par Mois')
plt.xlabel('Mois')
plt.ylabel('Consommation Moyenne (MW)')

# Ajouter plus de visualisations selon les besoins
# ...

# Afficher le graphique
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Interprétation des Visualisations des Données Énergétiques</h3>
#     <p>
#         Les visualisations fournissent un aperçu détaillé des dynamiques de consommation énergétique et de leur relation avec la température. La carte de chaleur indique une corrélation négative significative entre la consommation énergétique brute et la température moyenne, ce qui suggère que la consommation d'énergie augmente à mesure que la température baisse. Ceci est cohérent avec un besoin accru de chauffage durant les périodes froides.
#     </p>
#     <p>
#         Le graphique de la consommation moyenne par jour de la semaine montre une distribution relativement uniforme, indiquant qu'il n'y a pas de variation significative de la consommation d'énergie en fonction du jour de la semaine. Cela peut refléter une consommation d'énergie constante dans les secteurs résidentiels et commerciaux tout au long de la semaine.
#     </p>
#     <p>
#         La consommation moyenne par mois montre des variations saisonnières marquées, avec une consommation plus élevée durant les mois d'hiver et une baisse pendant les mois d'été. Cela met en évidence l'impact des conditions météorologiques et des changements de saison sur la consommation énergétique.
#     </p>
# </div>

# %%
# 1. Comparaison de la Consommation Énergétique avec la Température
fig, ax1 = plt.subplots(figsize=(14, 7))
ax2 = ax1.twinx()
ax1.plot(Conso_Energie['Consommation Brut (MW)'], color='blue', label='Consommation (MW)')
ax2.plot(Conso_Energie['Température moyenne (°C)'], color='red', label='Température (°C)')
ax1.set_xlabel('Date')
ax1.set_ylabel('Consommation (MW)', color='blue')
ax2.set_ylabel('Température (°C)', color='red')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.title('Comparaison de la Consommation Énergétique et de la Température')
plt.show()

# 2. Boxplots de la Consommation par Mois et par Jour de la Semaine
plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
sns.boxplot(data=Conso_Energie, x='Month', y='Consommation Brut (MW)')
plt.title('Distribution de la Consommation par Mois')

plt.subplot(1, 2, 2)
sns.boxplot(data=Conso_Energie, x='Weekday Name', y='Consommation Brut (MW)')
plt.title('Distribution de la Consommation par Jour de la Semaine')
plt.show()

# 3. Graphiques de Densité de la Consommation
plt.figure(figsize=(14, 7))
sns.kdeplot(data=Conso_Energie['Consommation Brut (MW)'], shade=True)
plt.title('Densité de la Consommation Énergétique')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# Sélection de la colonne 'Consommation_Diff'
series = Conso_Energie['Consommation Brut (MW)']

# Décomposition saisonnière de la série temporelle
decomposition = seasonal_decompose(series, model='additive', period=7)

# Création des graphiques pour chaque composant
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(12, 8))

decomposition.observed.plot(ax=ax1)
ax1.set_title('Observée')
ax1.set_ylabel('Consommation')

decomposition.trend.plot(ax=ax2)
ax2.set_title('Tendance')
ax2.set_ylabel('Tendance')

decomposition.seasonal.plot(ax=ax3)
ax3.set_title('Saisonnalité')
ax3.set_ylabel('Saisonnalité')

decomposition.resid.plot(ax=ax4)
ax4.set_title('Résidus')
ax4.set_ylabel('Résidus')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Interprétation des Résultats des Visualisations Énergétiques</h3>
#     <p>
#         Les graphiques obtenus offrent une analyse multidimensionnelle de la consommation énergétique. Le premier graphique montre une juxtaposition des variations de la température moyenne et de la consommation énergétique brute, révélant des motifs inverses qui peuvent indiquer une relation de cause à effet où la consommation augmente lorsque les températures chutent, possiblement dû à une utilisation accrue du chauffage pendant les périodes froides.
#     </p>
#     <p>
#         Le second graphique, présentant la distribution de la consommation par mois, met en lumière les fluctuations saisonnières significatives, avec des consommations plus élevées en hiver et plus basses en été. Cette variation peut être attribuée aux changements de comportement liés au chauffage et au refroidissement.
#     </p>
#     <p>
#         La distribution de la consommation par jour de la semaine, illustrée par le troisième graphique, démontre une relative uniformité, suggérant que les habitudes de consommation ne fluctuent pas considérablement d'un jour à l'autre au cours d'une semaine typique.
#     </p>
#     <p>
#         Enfin, le graphique de densité de la consommation énergétique brute dévoile deux pics principaux qui pourraient correspondre à des niveaux de consommation standard et des périodes de pointe. L'analyse de ces pics peut aider à comprendre les besoins énergétiques typiques ainsi que les événements ou conditions qui entraînent une consommation exceptionnellement élevée.
#     </p>
# </div>

# %%
# Supposons que 'Consommation Brut (MW)' est la colonne d'intérêt
consommation = Conso_Energie['Consommation Brut (MW)']

# Trouver les pics de consommation
peaks, _ = find_peaks(consommation, height=0)  # Vous pouvez ajuster le paramètre 'height' selon vos besoins

# Visualiser les pics sur un graphique de série temporelle
plt.figure(figsize=(12, 6))
plt.plot(consommation, label='Consommation Brut (MW)')
plt.plot(consommation.index[peaks], consommation.iloc[peaks], "x", label='Pics de Consommation')
plt.title('Pics dans la Consommation Énergétique')
plt.xlabel('Date')
plt.ylabel('Consommation Brut (MW)')
plt.legend()
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #4CAF50;">Interprétation des Pics de Consommation Énergétique</h3>
#     <p>
#         L'analyse des pics de consommation révèle des jours de demande énergétique particulièrement élevée. Ces pics sont souvent associés à des conditions climatiques extrêmes, des événements spéciaux ou des variations saisonnières. Par exemple, les pics observés en hiver, comme celui du 2021-01-05 avec une consommation de 77591.0 MW, pourraient coïncider avec des vagues de froid où l'utilisation du chauffage augmente significativement.
#     </p>
#     <p>
#         En examinant ces jours de pointe, nous pouvons identifier des tendances et des anomalies. Les pics survenant durant des périodes habituellement plus tempérées, comme le 2021-04-12 avec 54949.0 MW, peuvent indiquer des événements non saisonniers qui méritent une enquête plus approfondie, tels que des activités industrielles intenses ou des événements locaux.
#     </p>
#     <p>
#         Les périodes avec une fréquence accrue de pics, comme observées en janvier et février 2021, suggèrent des modèles de consommation qui pourraient être prévus et gérés par des stratégies d'efficacité énergétique ciblées. Ceci est crucial pour la planification des capacités de production d'énergie et pour la mise en place de mesures qui assurent la stabilité du réseau électrique.
#     </p>
#     <p>
#         Cette analyse met en évidence l'importance d'une surveillance continue et d'une analyse prédictive pour optimiser la gestion de l'énergie et minimiser les coûts, tout en garantissant la satisfaction des besoins des consommateurs pendant les périodes de demande accrue.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:4px;border-color:#4CAF50">
# <center><h1>Modélisation - ARIMA</h1></center>
# <hr style="border-width:4px;border-color:#4CAF50">

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">
#     Sélection du Modèle
# </h1>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Évaluation de la Stationnarité
# </span>
# <p style="font-size: 16px;">
#     Avant de choisir un modèle de prévision, il est essentiel de déterminer si notre série temporelle est stationnaire, car cela influence directement le type de modèle que nous pouvons appliquer. Une approche visuelle initiale, complétée par des tests statistiques comme le test de Dickey-Fuller augmenté, nous aidera à évaluer la stationnarité de notre série et à identifier la nécessité de différenciation ou de transformation des données.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Analyse des Fonctions d'Auto-Corrélation
# </span>
# <p style="font-size: 16px;">
#     L'analyse des fonctions d'auto-corrélation (ACF) et de corrélation partielle (PACF) nous permettra d'identifier les relations internes au sein de la série temporelle. Ces analyses sont cruciales pour la sélection des termes AR (Auto-Régressif) et MA (Moyenne Mobile) dans nos modèles ARIMA ou SARIMA, en indiquant le nombre de périodes passées qui influencent les valeurs actuelles.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Expérimentation avec Différents Modèles
# </span>
# <p style="font-size: 16px;">
#     Nous testerons différents modèles de prévision, en commençant par des modèles linéaires simples pour établir une base de référence, puis en progressant vers des modèles de machine learning plus complexes tels que le boosting par gradient ou les réseaux LSTM pour l'apprentissage profond. Chaque modèle sera évalué pour sa capacité à capturer les dynamiques de notre série et sa performance sera mesurée à l'aide de métriques telles que le RMSE (Root Mean Square Error).
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Modélisation et Validation
# </span>
# <p style="font-size: 16px;">
#     Une fois les modèles choisis, nous les ajusterons à nos données historiques et procéderons à des validations croisées pour évaluer leur robustesse et leur capacité de généralisation. Les modèles les plus performants seront ensuite utilisés pour faire des prévisions sur des données non vues, permettant d'éclairer la prise de décision stratégique et la gestion opérationnelle de la consommation d'énergie.
# </p>

# %%
def plot_time_series(df, column='Consommation Brut (MW)'):
    fig = px.line(df, x=df.index, y=column, title=f'Time Series Plot of {column}')
    fig.update_xaxes(title_text='Date')
    fig.update_yaxes(title_text='Valeurs')
    fig.show()
plot_time_series(Conso_Energie)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #4CAF50;">Interprétation Visuelle de la Stationnarité</h3>
#     <p>
#         L'analyse visuelle du graphique de dispersion des valeurs de consommation énergétique brute montre des fluctuations notables dans la série temporelle. Il est évident que la consommation énergétique présente une saisonnalité annuelle, avec des pics pendant les périodes hivernales et des creux pendant les périodes estivales, ce qui suggère une non-stationnarité saisonnière. De plus, l'amplitude des pics et des creux semble augmenter au fil du temps, indiquant une possible tendance et une variance croissante, deux autres signes de non-stationnarité.
#     </p>
#     <p>
#         Avant de procéder à des tests statistiques plus formels, cette observation visuelle préliminaire suggère que la série temporelle pourrait nécessiter une différenciation saisonnière ou des transformations pour stabiliser la variance et éliminer la tendance, afin de la rendre stationnaire pour une modélisation plus efficace.
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Test de la Stationnarité</h1>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h3 style="color: #339966;">Analyse de la Stationnarité des Séries Temporelles</h3>
#     <p>
#         L'objectif de cette partie est de déterminer la stationnarité de la série temporelle de la consommation énergétique brute. La stationnarité est un attribut crucial des séries temporelles qui affecte la sélection des modèles prédictifs et la validité des prévisions.
#     </p>
#     <p>
#         Pour évaluer la stationnarité, nous appliquons trois tests statistiques :
#     </p>
#     <ul>
#         <li>
#             <strong>Le test Augmented Dickey-Fuller (ADF)</strong> examine l'hypothèse nulle selon laquelle une série possède une racine unitaire, indiquant une possible non-stationnarité.
#         </li>
#         <li>
#             <strong>Le test Phillips-Perron (PP)</strong> teste également la présence d'une racine unitaire dans la série, mais il est robuste face à de nombreuses formes de dépendance sérielle et de tendances déterministes.
#         </li>
#         <li>
#             <strong>Le test Kwiatkowski-Phillips-Schmidt-Shin (KPSS)</strong> a pour hypothèse nulle la stationnarité autour d'une tendance, avec l'alternative étant la non-stationnarité.
#         </li>
#     </ul>
#     <p>
#         Les résultats combinés de ces tests nous permettent d'établir une conclusion sur la stationnarité de la série temporelle. Une procédure de décision basée sur les valeurs p des tests nous aide à déterminer si la série est <em>stationnaire</em> ou <em>non-stationnaire</em>. Ces informations sont essentielles pour le développement de modèles prévisionnels fiables et pour la planification stratégique dans le secteur énergétique.
#     </p>
#     <p>
#         Les résultats de l'analyse de stationnarité sont récapitulés dans un tableau pour une interprétation claire. En cas de résultats indiquant une non-stationnarité, des étapes de différenciation ou de transformation des données peuvent être nécessaires avant de procéder à la modélisation prédictive.
#     </p>
# </div>

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller, kpss
from arch.unitroot import PhillipsPerron

def stationnarite(data, var):
    sig = 0.05  # Seuil de signification
    res_df = pd.DataFrame()  # Créer un DataFrame vide
    
    # Test ADF
    adf_test = adfuller(data[var], autolag='AIC')
    
    # Test Phillips-Perron
    pp_test = PhillipsPerron(data[var])
    
    # Test KPSS
    kpss_test = kpss(data[var], nlags="auto", regression='c')
    
    # Interprétation des résultats
    flag = 'Indéterminé'
    if (adf_test[1] < sig) and (pp_test.pvalue < sig) and (kpss_test[1] > sig):
        flag = 'Stationnaire'
    elif (adf_test[1] > sig) or (pp_test.pvalue > sig) or (kpss_test[1] < sig):
        flag = 'Non-stationnaire'
    
    new_row = pd.Series({
        'Variable': var.upper(),
        'Statistique ADF': adf_test[0],
        'p-valeur ADF': adf_test[1],
        'Statistique PP': pp_test.stat,
        'p-valeur PP': pp_test.pvalue,
        'Statistique KPSS': kpss_test[0],
        'p-valeur KPSS': kpss_test[1],
        'Drapeau de stationnarité': flag
    })

    res_df = pd.concat([res_df, new_row.to_frame().T], ignore_index=True)
    
    return res_df

# Utilisation de l'exemple (à exécuter avec vos données réelles) :
# Remplacez 'your_dataframe' par votre DataFrame et 'Consommation Brut (MW)' par le nom de votre colonne
resultats_stationnarite = stationnarite(Conso_Energie, 'Consommation Brut (MW)')
resultats_stationnarite
# Out:
#                  Variable Statistique ADF p-valeur ADF Statistique PP  \
# 0  CONSOMMATION BRUT (MW)       -2.809364     0.056949      -7.311162
#
#   p-valeur PP Statistique KPSS p-valeur KPSS Drapeau de stationnarité
# 0         0.0         0.250797           0.1         Non-stationnaire

# %%
def visualize_adfuller_results(series, title, ax):
    result = adfuller(series)
    significance_level = 0.05
    adf_stat = result[0]
    p_val = result[1]
    crit_val_1 = result[4]['1%']
    crit_val_5 = result[4]['5%']
    crit_val_10 = result[4]['10%']
    
    # Determine if the series is stationary and set the line color
    if p_val < significance_level:
        linecolor = 'forestgreen'
        stationarity = 'Stationary'
    else:
        linecolor = 'purple'
        stationarity = 'Non-Stationary'
    
    sns.lineplot(x=series.index, y=series, ax=ax, color=linecolor)
    ax.set_title(f'{title} - ADF Statistic: {adf_stat:.3f}, p-value: {p_val:.3f}\nConclusion: {stationarity}', fontsize=14)
    ax.set_ylabel('Values')
    ax.axhline(y=crit_val_1, color='red', linestyle='--', label='1% Critical Value')
    ax.axhline(y=crit_val_5, color='orange', linestyle='--', label='5% Critical Value')
    ax.axhline(y=crit_val_10, color='green', linestyle='--', label='10% Critical Value')
    ax.legend()

# Create subplots
fig, ax = plt.subplots(figsize=(14, 7))

# Visualizing the ADF test results on your time series data
visualize_adfuller_results(Conso_Energie['Consommation Brut (MW)'], 'Consommation Brut (MW)', ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h3 style="color: #339966;">Interprétation des Tests de Stationnarité</h3>
#     <p>
#         Les résultats des tests de stationnarité pour la variable <strong>Consommation Brut (MW)</strong> sont les suivants :
#     </p>
#     <ul>
#         <li>
#             <strong>Test ADF (Augmented Dickey-Fuller)</strong>:
#             <ul>
#                 <li><strong>H0</strong>: La série temporelle possède une racine unitaire (non-stationnaire).</li>
#                 <li><strong>HA</strong>: La série temporelle n'a pas de racine unitaire (stationnaire).</li>
#                 <li><strong>Résultat</strong>: Une statistique ADF de -2.809364 avec une p-valeur de 0.056949 suggère que nous ne pouvons pas rejeter H0 avec une confiance élevée, indiquant que la série pourrait être non-stationnaire.</li>
#             </ul>
#         </li>
#         <li>
#             <strong>Test PP (Phillips-Perron)</strong>:
#             <ul>
#                 <li><strong>H0</strong>: La série temporelle a une racine unitaire (non-stationnaire).</li>
#                 <li><strong>HA</strong>: La série temporelle est stationnaire.</li>
#                 <li><strong>Résultat</strong>: Une statistique PP de -7.311162 avec une p-valeur de 0.0 nous amène à rejeter H0, indiquant que la série est stationnaire.</li>
#             </ul>
#         </li>
#         <li>
#             <strong>Test KPSS (Kwiatkowski-Phillips-Schmidt-Shin)</strong>:
#             <ul>
#                 <li><strong>H0</strong>: La série temporelle est stationnaire autour d'une tendance ou moyenne.</li>
#                 <li><strong>HA</strong>: La série temporelle est non-stationnaire (présence de racine unitaire).</li>
#                 <li><strong>Résultat</strong>: Avec une statistique KPSS de 0.250797 et une p-valeur de 0.1, nous ne rejetons pas H0, ce qui suggère que la série pourrait être stationnaire autour d'une tendance ou moyenne.</li>
#             </ul>
#         </li>
#     </ul>
#     <p>
#         Les résultats du test ADF suggèrent une possible non-stationnarité tandis que les tests PP et KPSS indiquent une stationnarité. Cette divergence des résultats peut être due à la présence de tendances ou de composantes saisonnières dans la série temporelle. Avant de procéder à la modélisation prédictive, il pourrait être nécessaire d'appliquer des transformations telles que la différenciation ou le lissage exponentiel pour stabiliser la variance et la moyenne de la série..
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Différenciation Première</h1>

# %%
# Différenciation première de la série temporelle
Conso_Energie['Consommation_Diff'] = Conso_Energie['Consommation Brut (MW)'].diff()

# Suppression des valeurs NaN créées par la différenciation
Conso_Energie_Diff_Clean = Conso_Energie.dropna(subset=['Consommation_Diff'])

#Conso_Energie_Diff_Clean.to_excel("Data/Conso_Energie_Diff_Clean.xlsx")

# %%
def visualize_adfuller_results(series, title, ax):
    result = adfuller(series)
    significance_level = 0.05
    adf_stat = result[0]
    p_val = result[1]
    crit_val_1 = result[4]['1%']
    crit_val_5 = result[4]['5%']
    crit_val_10 = result[4]['10%']
    
    # Determine if the series is stationary and set the line color
    if p_val < significance_level:
        linecolor = 'forestgreen'
        stationarity = 'Stationary'
    else:
        linecolor = 'purple'
        stationarity = 'Non-Stationary'
    
    sns.lineplot(x=series.index, y=series, ax=ax, color=linecolor)
    ax.set_title(f'{title} - ADF Statistic: {adf_stat:.3f}, p-value: {p_val:.3f}\nConclusion: {stationarity}', fontsize=14)
    ax.set_ylabel('Values')
    ax.axhline(y=crit_val_1, color='red', linestyle='--', label='1% Critical Value')
    ax.axhline(y=crit_val_5, color='orange', linestyle='--', label='5% Critical Value')
    ax.axhline(y=crit_val_10, color='green', linestyle='--', label='10% Critical Value')
    ax.legend()

# Create subplots
fig, ax = plt.subplots(figsize=(14, 7))

# Visualizing the ADF test results on your time series data
visualize_adfuller_results(Conso_Energie_Diff_Clean['Consommation_Diff'], 'Consommation_Diff', ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Interprétation des Résultats de Stationnarité</h3>
#     <p>
#         Après la différenciation première, la série temporelle de la consommation énergétique brute montre des variations centrées autour de zéro, sans tendance claire ou saisonnalité apparente. Le test Augmented Dickey-Fuller (ADF) renvoie une statistique de test de -7.658 et une valeur-p de 0.000, ce qui suggère fortement que la série différenciée est stationnaire. Les valeurs critiques pour les seuils de 1%, 5% et 10% sont respectivement dépassées par la statistique de test, confirmant davantage la stationnarité de la série.
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Sélection des Ordres pour le Modèle ARIMA</h1>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Sélection des Ordres pour le Modèle ARIMA</h3>
#     <p>
#         L'identification des ordres appropriés pour le modèle ARIMA est une étape cruciale pour la modélisation de séries temporelles. Elle implique l'analyse des fonctions d'autocorrélation (ACF) et d'autocorrélation partielle (PACF) pour déterminer les paramètres p (ordre du terme autorégressif AR), d (ordre de différenciation), et q (ordre du terme de moyenne mobile MA).
#     </p>
#     <p>
#         La fonction ACF nous aide à identifier l'ordre potentiel de la composante MA du modèle, en observant le décalage où la corrélation décroît rapidement vers zéro. D'autre part, la fonction PACF est utilisée pour détecter l'ordre de la composante AR, en cherchant le dernier décalage significatif avant que les corrélations ne se stabilisent autour de zéro.
#     </p>
#     <p>
#         Nous allons générer les graphiques ACF et PACF pour notre série temporelle différenciée et interpréter visuellement les données pour estimer les paramètres du modèle ARIMA. Les graphiques nous permettront de choisir des valeurs initiales pour p, d, et q, que nous affinerons ensuite à l'aide d'une approche itérative de modélisation et de validation.
#     </p>
# </div>

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Sélection de la colonne 'Consommation_Diff'
series = Conso_Energie_Diff_Clean['Consommation_Diff']

# Création des graphiques pour l'analyse exploratoire
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

# Tracer la série temporelle
axes[0].plot(series)
axes[0].set_title('Série temporelle de la différence de consommation d\'énergie')

# Tracer l'Autocorrélogramme (ACF)
sm.graphics.tsa.plot_acf(series, ax=axes[1], lags=40)
axes[1].set_title('Autocorrélogramme (ACF)')

# Tracer le Partielle Autocorrélogramme (PACF)
sm.graphics.tsa.plot_pacf(series, ax=axes[2], lags=40)
axes[2].set_title('Partielle Autocorrélogramme (PACF)')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="font-family: Arial, sans-serif; color: #333; font-size: 14px;">
#     <h2 style="color: #75DFC1;">Interprétation des fonctions ACF et PACF</h2>
#     <p>
#         Les fonctions ACF et PACF pour notre série temporelle après différenciation montrent des pics significatifs qui s'étendent au-delà de l'intervalle de confiance, indiquant des autocorrélations notables à plusieurs retards. Cela suggère que la série temporelle ne peut pas être modélisée par un simple modèle de moyenne mobile (MA).
#     </p>
#     <p>
#         De manière similaire, la PACF présente également des pics significatifs à divers intervalles, réfutant l'idée d'un modèle autorégressif (AR) simple. L'observation des pics s'étendant à des retards supérieurs dans les deux fonctions suggère que la structure de la série temporelle est complexe et bénéficierait d'un modèle combinant les composantes AR et MA.
#     </p>
#     <p>
#         Par conséquent, une sélection automatique des paramètres à l'aide de la méthode auto_arima est justifiée pour identifier un modèle ARIMA approprié qui capture à la fois les autorégressions et les moyennes mobiles inhérentes à la série.
#     </p>
#     <p>
#         Il est également essentiel de considérer la possibilité de termes saisonniers qui pourraient expliquer d'autres variations non capturées par les modèles ARIMA non saisonniers, ce qui pourrait mener à l'élaboration d'un modèle SARIMA.
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Séparer les données en Train et Test</h1>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h3 style="color: #75DFC1;">Comparaison des Prédictions avec les Données Réelles pour 2023</h3>
#     <p>
#         L'année 2023 représente notre horizon de prévision. Après avoir formé notre modèle sur les données 2020 à 2022, nous nous concentrons désormais exclusivement sur cette année pour évaluer la précision de nos prédictions.
#     </p>
#     <p>
#         Les prédictions générées par le modèle seront mises en parallèle avec les valeurs réelles de la consommation d'énergie pour l'ensemble de l'année 2023. Cette comparaison directe entre les données prédites et observées nous permettra d'évaluer l'efficacité de notre modèle et d'identifier les éventuelles améliorations nécessaires.
#     </p>
# </div>

# %%
# Définition de la date de séparation
date_separation = '2022-12-31'
# Séparation en ensembles de formation et de test
serie_form = Conso_Energie_Diff_Clean['Consommation_Diff'][Conso_Energie_Diff_Clean.index <= pd.to_datetime(date_separation)]
serie_2023 = Conso_Energie_Diff_Clean['Consommation_Diff'][Conso_Energie_Diff_Clean.index > pd.to_datetime(date_separation)]

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Modèle ARIMA</h1>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h2 style="color: #75DFC1;">Sélection du Modèle Prédictif</h2>
#     <p>
#         Dans cette étape cruciale de notre analyse, nous allons déterminer le modèle prédictif le plus adapté pour notre série temporelle de différences de consommation énergétique. Notre objectif est de trouver un modèle qui capture au mieux les caractéristiques intrinsèques de nos données, y compris les tendances et la saisonnalité, afin de faire des prévisions précises pour l'avenir.
#     </p>
#     <p>
#         Pour ce faire, nous utiliserons la fonction <code>auto_arima</code> de la bibliothèque <code>pmdarima</code> en Python, qui va nous permettre de tester automatiquement plusieurs combinaisons de paramètres pour les modèles ARIMA et SARIMA. Ce processus implique la recherche du meilleur ensemble de paramètres (p, d, q) pour le modèle ARIMA et (P, D, Q, m) pour la composante saisonnière SARIMA, qui minimisent le critère d'information d'Akaike (AIC) ou le critère d'information bayésien (BIC), indiquant un meilleur ajustement du modèle.
#     </p>
#     <p>
#         <ul>
#             <li><code>start_p</code> et <code>start_q</code> indiquent les points de départ de la recherche pour les ordres du modèle AR et MA.</li>
#             <li><code>max_p</code> et <code>max_q</code> définissent les limites maximales pour les ordres du modèle AR et MA.</li>
#             <li><code>m</code> représente la périodicité saisonnière des données.</li>
#             <li><code>start_P</code>, <code>d</code>, <code>D</code> et les options saisonnières permettent de tester les composantes saisonnières du modèle.</li>
#             <li><code>trace</code> active l'affichage des étapes de la recherche, offrant une transparence dans la sélection du modèle.</li>
#             <li><code>stepwise</code> active l'optimisation pas à pas qui accélère la recherche du meilleur modèle.</li>
#         </ul>
#     </p>
#     <p>
#         À la fin du processus, nous obtiendrons un résumé détaillé du meilleur modèle trouvé. Ce résumé nous donnera des informations précieuses sur les paramètres sélectionnés ainsi que sur les statistiques de performance du modèle, nous permettant de juger de l'adéquation du modèle choisi pour nos besoins de prévision.
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Modèle1 : Sélection d'ordre - ARIMA : </h1>

# %%
from pmdarima import auto_arima
import numpy as np
import pandas as pd
import random

# Fixer la graine aléatoire pour la reproductibilité
np.random.seed(123)
random.seed(123)

# Assurez-vous que la colonne 'Consommation_Diff' est votre série temporelle
# et que 'Conso_Energie_Diff_Clean' est votre DataFrame
# Remplacer 'Conso_Energie_Diff_Clean' avec votre DataFrame réel
series = Conso_Energie_Diff_Clean['Consommation_Diff'].dropna()  # Éliminer les valeurs NaN pour éviter les erreurs lors de la modélisation

# Utiliser auto_arima pour trouver le meilleur modèle ARIMA
model = auto_arima(series,
                   start_p=0, start_q=0,  # Points de départ initiaux pour p et q
                   max_p=5, max_q=5,      # Limites supérieures pour p et q
                   m=12,                  # Fréquence saisonnière des données
                   start_P=0,             # Point de départ initial pour P
                   seasonal=True,         # Indique si le modèle doit inclure des composants saisonniers
                   d=None, D=None,           # d est la différenciation non saisonnière, D la saisonnière
                   trace=True,            # Affiche le déroulement de la recherche des meilleurs paramètres
                   error_action='ignore', # Ignore les ordres qui ne convergent pas lors de la recherche
                   suppress_warnings=True,# Supprime les avertissements pour un affichage propre
                   stepwise=True,         # Utilise l'algorithme stepwise pour une recherche efficace
                   random_state=123)      # Permet la reproductibilité des résultats de recherche

# Affiche le résumé du modèle pour examiner les paramètres sélectionnés
#print(model.summary())

# Enregistrement des paramètres du modèle pour l'initialisation future
best_params = model.get_params()

# Initialisation d'un modèle ARIMA avec les paramètres obtenus
# Cela permet d'assurer la cohérence lors de la réutilisation du modèle
# Par exemple : ARIMA(p=best_params['order'][0], d=best_params['order'][1], q=best_params['order'][2])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=27353.069, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=27483.917, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=27349.119, Time=0.28 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=27251.819, Time=0.51 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=27481.917, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=27422.598, Time=0.11 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=27250.293, Time=0.78 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=27323.925, Time=0.46 sec
#  ARIMA(0,0,1)(2,0,1)[12] intercept   : AIC=27138.539, Time=1.60 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=27109.045, Time=2.82 sec
#  ARIMA(0,0,0)(2,0,0)[12] intercept   : AIC=27336.903, Time=0.55 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=27085.525, Time=2.09 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=27161.959, Time=0.88 sec
# ...

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Entrainer Modèle1 - ARIMA : </h1>

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Supposons que 'serie_temporelle' est votre série temporelle nettoyée et prête pour l'analyse
# Remplacer 'serie_temporelle' avec votre série temporelle réelle
series = Conso_Energie_Diff_Clean['Consommation_Diff'].dropna()  # Éliminer les valeurs NaN pour éviter les erreurs lors de la modélisation

# Initialisation du modèle SARIMAX avec les paramètres obtenus
model_1 = SARIMAX(serie_form,
                order=(5, 0, 5),              # Paramètres ARIMA (p, d, q)
                seasonal_order=(0, 0, 0, 12), # Paramètres saisonniers (P, D, Q, S)
                enforce_stationarity=False,   # Ne pas forcer la stationnarité
                enforce_invertibility=False)  # Ne pas forcer l'inversibilité

# Ajustement du modèle
fitted_model_1 = model_1.fit(disp=0)

# Vous pouvez maintenant utiliser fitted_model pour faire des prédictions
print(fitted_model_1.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:      Consommation_Diff   No. Observations:                 1088
# Model:               SARIMAX(5, 0, 5)   Log Likelihood              -10132.348
# Date:                Thu, 11 Jan 2024   AIC                          20286.696
# Time:                        22:25:17   BIC                          20341.548
# Sample:                    01-09-2020   HQIC                         20307.463
#                          - 12-31-2022
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4238      0.032     13.067      0.000       0.360       0.487
# ar.L2         -1.1062      0.029    -38.122      0.000      -1.163      -1.049
# ar.L3          0.2350      0.047      4.993      0.000       0.143       0.327
# ...

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Test et Prévision Modèle1 - ARIMA : </h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# ... [autres imports et initialisations] ...

# Prédictions pour l'année 2023
start_pred = '2023-01-01'
end_pred = '2023-11-30'
forecast = fitted_model_1.get_prediction(start=start_pred, end=end_pred)
forecast_index = pd.date_range(start=start_pred, end=end_pred, freq='D')  # Ajustez la fréquence si nécessaire

# Obtenir les valeurs prédites et l'intervalle de confiance
predicted_mean = forecast.predicted_mean
predicted_ci = forecast.conf_int()

# Tracer les valeurs réelles pour 2023 (si disponibles)
plt.figure(figsize=(14, 7))
if 'serie_2023' in locals() or 'serie_2023' in globals():
    plt.plot(serie_2023.index, serie_2023, label='Valeurs réelles pour 2023')

# Assurez-vous que les index de prévision et les données réelles sont alignés
if len(forecast_index) == len(predicted_mean):
    plt.plot(forecast_index, predicted_mean, color='red', label='Prévisions pour 2023')
    plt.fill_between(forecast_index, predicted_ci.iloc[:, 0], predicted_ci.iloc[:, 1], color='pink', alpha=0.3)
else:
    print("Erreur : les longueurs des données de prévision et réelles ne correspondent pas.")
    
    
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Aligner les séries temporelles sur l'index commun
common_index = serie_2023.index.intersection(predicted_mean.index)
aligned_real_values = serie_2023.loc[common_index]
aligned_predicted_values = predicted_mean.loc[common_index]

# Vérifier si elles sont maintenant de la même longueur
if len(aligned_real_values) == len(aligned_predicted_values):
    # Calculer les métriques de performance
    rmse = np.sqrt(mean_squared_error(aligned_real_values, aligned_predicted_values))
    mae = mean_absolute_error(aligned_real_values, aligned_predicted_values)
    r2 = r2_score(aligned_real_values, aligned_predicted_values)

    print(f'Aligned RMSE: {rmse}')
    print(f'Aligned MAE: {mae}')
    print(f'Aligned R^2: {r2}')
else:
    print("Les séries ne sont toujours pas alignées correctement.")

plt.title('Comparaison des Prévisions et des Valeurs Réelles pour 2023')
plt.legend()
plt.show()
# Out:
# Aligned RMSE: 2659.521875028788
# Aligned MAE: 1934.6400039675068
# Aligned R^2: 0.2791247206721482

# %% [markdown]
# <div style="font-family: Arial, sans-serif; color: #333; font-size: 14px;">
#     <h2 style="color: #75DFC1;">Interprétation du Modèle SARIMAX(5, 0, 5)</h2>
#     <p>
#         L'analyse du modèle SARIMAX(5, 0, 5) pour la série temporelle 'Consommation_Diff' suggère des dynamiques complexes de consommation énergétique. La combinaison de cinq termes autorégressifs (AR) et cinq moyennes mobiles (MA) reflète une interdépendance significative entre les valeurs passées et la capacité du modèle à capter des cycles et des tendances spécifiques. Cependant, le RMSE relativement élevé de 2659.52 et le R² de 0.2791 montrent que bien que le modèle suive certaines tendances, il reste un écart substantiel entre les prévisions et les valeurs réelles.
#     </p>
#     <p>
#         Cette réalité souligne la nécessité d'explorer davantage d'ordres et de modèles, tels que SARIMA et SARIMAX, pour trouver une correspondance plus précise avec les données observées. La poursuite de cette exploration est essentielle pour améliorer la précision des prévisions et répondre plus finement à la complexité inhérente à la consommation énergétique.
#     </p>
#     <p>
#         En parallèle, l'attention doit être portée sur les avertissements concernant la matrice de covariance, qui, étant proche de la singularité, peut signaler des erreurs standard potentiellement instables. Cela implique que le modèle pourrait bénéficier d'une réduction de la complexité ou d'une sélection de caractéristiques plus ciblée.
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Modèle2 : Sélection d'ordre - SARIMA : </h1>

# %%
from pmdarima import auto_arima
import numpy as np
import pandas as pd
import random

# Fixer la graine aléatoire pour la reproductibilité
np.random.seed(123)
random.seed(123)


series = Conso_Energie_Diff_Clean['Consommation_Diff'].dropna()  # Éliminer les valeurs NaN pour éviter les erreurs lors de la modélisation

# Utiliser auto_arima pour trouver le meilleur modèle ARIMA
model = auto_arima(series,
                   start_p=0, start_q=0,  # Points de départ initiaux pour p et q
                   max_p=5, max_q=5,      # Limites supérieures pour p et q
                   m=12,                  # Fréquence saisonnière des données
                   start_P=0,             # Point de départ initial pour P
                   seasonal=True,         # Indique si le modèle doit inclure des composants saisonniers
                   d=None, D=1,           # d est la différenciation non saisonnière, D la saisonnière
                   trace=True,            # Affiche le déroulement de la recherche des meilleurs paramètres
                   error_action='ignore', # Ignore les ordres qui ne convergent pas lors de la recherche
                   suppress_warnings=True,# Supprime les avertissements pour un affichage propre
                   stepwise=True,         # Utilise l'algorithme stepwise pour une recherche efficace
                   random_state=123)      # Permet la reproductibilité des résultats de recherche

# Affiche le résumé du modèle pour examiner les paramètres sélectionnés
#print(model.summary())

# Enregistrement des paramètres du modèle pour l'initialisation future
best_params = model.get_params()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=1.90 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=28567.949, Time=0.10 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=28027.376, Time=2.91 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=6.56 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=28566.000, Time=0.07 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=28552.499, Time=0.10 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=27835.859, Time=2.42 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=27407.952, Time=14.48 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=7.23 sec
#  ARIMA(1,0,0)(2,1,2)[12] intercept   : AIC=27393.422, Time=17.98 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=27451.881, Time=17.39 sec
#  ARIMA(0,0,0)(2,1,2)[12] intercept   : AIC=inf, Time=15.29 sec
#  ARIMA(2,0,0)(2,1,2)[12] intercept   : AIC=27269.975, Time=21.04 sec
# ...

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Entrainer Modèle2 - SARIMA : </h1>

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Supposons que 'serie_temporelle' est votre série temporelle nettoyée et prête pour l'analyse
# Remplacer 'serie_temporelle' avec votre série temporelle réelle
#series = Conso_Energie_Diff_Clean['Consommation_Diff'].dropna()  # Éliminer les valeurs NaN pour éviter les erreurs lors de la modélisation

# Initialisation du modèle SARIMAX avec les paramètres obtenus
model = SARIMAX(serie_form,
                order=(5, 0, 5),              # Paramètres ARIMA (p, d, q)
                seasonal_order=(2, 1, 1, 12), # Paramètres saisonniers (P, D, Q, S)
                enforce_stationarity=False,   # Ne pas forcer la stationnarité
                enforce_invertibility=False)  # Ne pas forcer l'inversibilité
# Ajustement du modèle
fitted_model_2 = model.fit(disp=0)

# Vous pouvez maintenant utiliser fitted_model pour faire des prédictions
print(fitted_model_2.summary())
# Out:
#                                       SARIMAX Results
# ...
# Dep. Variable:                    Consommation_Diff   No. Observations:                 1088
# Model:             SARIMAX(5, 0, 5)x(2, 1, [1], 12)   Log Likelihood               -9970.194
# Date:                              Thu, 11 Jan 2024   AIC                          19968.388
# Time:                                      22:40:26   BIC                          20037.740
# Sample:                                  01-09-2020   HQIC                         19994.688
#                                        - 12-31-2022
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4078      0.067      6.113      0.000       0.277       0.539
# ar.L2         -1.0910      0.059    -18.401      0.000      -1.207      -0.975
# ...

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Test et Prévision Modèle2 - SARIMA : </h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# ... [autres imports et initialisations] ...

# Prédictions pour l'année 2023
start_pred = '2023-01-01'
end_pred = '2023-11-30'
forecast = fitted_model_2.get_prediction(start=start_pred, end=end_pred)
forecast_index = pd.date_range(start=start_pred, end=end_pred, freq='D')  # Ajustez la fréquence si nécessaire

# Obtenir les valeurs prédites et l'intervalle de confiance
predicted_mean = forecast.predicted_mean
predicted_ci = forecast.conf_int()

# Tracer les valeurs réelles pour 2023 (si disponibles)
plt.figure(figsize=(14, 7))
if 'serie_2023' in locals() or 'serie_2023' in globals():
    plt.plot(serie_2023.index, serie_2023, label='Valeurs réelles pour 2023')

# Assurez-vous que les index de prévision et les données réelles sont alignés
if len(forecast_index) == len(predicted_mean):
    plt.plot(forecast_index, predicted_mean, color='red', label='Prévisions pour 2023')
    plt.fill_between(forecast_index, predicted_ci.iloc[:, 0], predicted_ci.iloc[:, 1], color='pink', alpha=0.3)
else:
    print("Erreur : les longueurs des données de prévision et réelles ne correspondent pas.")
    
    
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Aligner les séries temporelles sur l'index commun
common_index = serie_2023.index.intersection(predicted_mean.index)
aligned_real_values = serie_2023.loc[common_index]
aligned_predicted_values = predicted_mean.loc[common_index]

# Vérifier si elles sont maintenant de la même longueur
if len(aligned_real_values) == len(aligned_predicted_values):
    # Calculer les métriques de performance
    rmse = np.sqrt(mean_squared_error(aligned_real_values, aligned_predicted_values))
    mae = mean_absolute_error(aligned_real_values, aligned_predicted_values)
    r2 = r2_score(aligned_real_values, aligned_predicted_values)

    print(f'Aligned RMSE: {rmse}')
    print(f'Aligned MAE: {mae}')
    print(f'Aligned R^2: {r2}')
else:
    print("Les séries ne sont toujours pas alignées correctement.")

plt.title('Comparaison des Prévisions et des Valeurs Réelles pour 2023')
plt.legend()
plt.show()
# Out:
# Aligned RMSE: 2698.1719795059175
# Aligned MAE: 2031.679285013463
# Aligned R^2: 0.25801990491680216

# %% [markdown]
# <div style="font-family: Arial, sans-serif; color: #333; font-size: 14px;">
#     <h2 style="color: #75DFC1;">Interprétation des Résultats du Modèle SARIMAX</h2>
#     <p>
#         Notre modèle SARIMAX(5, 0, 5)x(2, 1, [1], 12) montre une adéquation avec les données observées, comme le suggère le RMSE aligné de 2698.17. Bien que le modèle capture certains aspects de la consommation énergétique, il existe un espace pour améliorer la précision, comme indiqué par le R² de 0.258.
#     </p>
#     <p>
#         Les termes AR et MA sélectionnés reflètent une dynamique complexe de la consommation énergétique. Cependant, la présence d'une matrice de covariance presque singulière indique que le modèle pourrait être amélioré pour renforcer la stabilité des estimations des paramètres.
#     </p>
#     <p>
#         Dans la continuité de notre analyse, nous explorerons d'autres configurations SARIMA et SARIMAX, en quête d'un modèle qui offre une meilleure performance. L'objectif est d'affiner nos prévisions pour qu'elles soient non seulement précises mais aussi robustes face à la variabilité inhérente aux données énergétiques.
#     </p>
#     <p>
#         L'évaluation continue des modèles est essentielle pour parvenir à une stratégie de prévision optimale. Les résultats actuels servent de point de départ pour des analyses plus poussées et des ajustements affinés des paramètres du modèle.
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Modèle3 : Sélection d'ordre - SARIMAX : </h1>

# %%
from pmdarima import auto_arima

# Sélection des colonnes exogènes potentielles (nous pourrions en ajouter ou en retirer selon les besoins)
exog_data = Conso_Energie_Diff_Clean[['Température moyenne (°C)', 'IsHoliday']]


# Définition de la date de séparation pour les ensembles de formation et de test
date_separation = '2022-12-31'

# Séparation en ensembles de formation et de test pour la cible et les données exogènes
serie_form = Conso_Energie_Diff_Clean['Consommation_Diff'][Conso_Energie_Diff_Clean.index <= pd.to_datetime(date_separation)]
serie_2023 = Conso_Energie_Diff_Clean['Consommation_Diff'][Conso_Energie_Diff_Clean.index > pd.to_datetime(date_separation)]
exog_form = exog_data[Conso_Energie_Diff_Clean.index <= pd.to_datetime(date_separation)]
exog_2023 = exog_data[Conso_Energie_Diff_Clean.index > pd.to_datetime(date_separation)]

# Utiliser auto_arima pour trouver le meilleur modèle ARIMA en incluant les données exogènes
model_with_exog = auto_arima(serie_form,
                             exogenous=exog_form,
                             start_p=0, start_q=0,
                             max_p=5, max_q=5,
                             m=12,
                             start_P=0, start_Q=0,
                             max_P=5, max_Q=5,
                             seasonal=True,
                             d=None, D=1,
                             trace=True,
                             error_action='ignore',
                             suppress_warnings=True,
                             stepwise=True,
                             random_state=123)

# Affiche le résumé du modèle pour examiner les paramètres sélectionnés
model_with_exog.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=21943.221, Time=0.05 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=21590.840, Time=0.62 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=4.23 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=21941.298, Time=0.06 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=21920.526, Time=0.09 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=21167.581, Time=5.93 sec
#  ARIMA(1,0,0)(3,1,0)[12] intercept   : AIC=20991.188, Time=13.58 sec
#  ARIMA(1,0,0)(4,1,0)[12] intercept   : AIC=20973.312, Time=32.07 sec
#  ARIMA(1,0,0)(5,1,0)[12] intercept   : AIC=20973.288, Time=66.35 sec
#  ARIMA(1,0,0)(5,1,1)[12] intercept   : AIC=inf, Time=80.08 sec
#  ARIMA(1,0,0)(4,1,1)[12] intercept   : AIC=20928.846, Time=41.99 sec
#  ARIMA(1,0,0)(3,1,1)[12] intercept   : AIC=21074.645, Time=25.42 sec
#  ARIMA(1,0,0)(4,1,2)[12] intercept   : AIC=inf, Time=48.22 sec
# ...

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);"> Entrainer et Prévision Modèle3 - SARIMAX : </h1>

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt

# Paramètres du modèle SARIMAX sélectionnés par auto_arima
order = (6, 0, 5)
seasonal_order = (2, 1, 1, 12)

# Séparation des données en ensembles de formation et de test
date_separation = '2022-12-31'
serie_form = Conso_Energie_Diff_Clean[Conso_Energie_Diff_Clean.index <= pd.to_datetime(date_separation)]
serie_2023 = Conso_Energie_Diff_Clean[Conso_Energie_Diff_Clean.index > pd.to_datetime(date_separation)]

# Sélection des variables exogènes pour l'entraînement et le test
exog_form = serie_form[['Température moyenne (°C)', 'IsHoliday']] #, 'Month', 'Day', 'Weekday', 'DayOfWeek', 'IsWeekend'
exog_2023 = serie_2023[['Température moyenne (°C)', 'IsHoliday']] #, 'Month', 'Day', 'Weekday', 'DayOfWeek', 'IsWeekend'

# Entraînement du modèle SARIMAX avec les meilleurs paramètres trouvés et les variables exogènes
model_sarimax = SARIMAX(serie_form['Consommation_Diff'],
                         exog=exog_form,
                         order=order,
                         seasonal_order=seasonal_order,
                         enforce_stationarity=False,
                         enforce_invertibility=False)
fitted_model = model_sarimax.fit(disp=False)


print(fitted_model.summary())
# Prédiction sur l'ensemble de test avec les variables exogènes correspondantes
predictions = fitted_model.get_forecast(steps=len(serie_2023), exog=exog_2023)
predictions_series = predictions.predicted_mean

# Évaluation des prédictions
rmse = np.sqrt(mean_squared_error(serie_2023['Consommation_Diff'], predictions_series))
r2 = r2_score(serie_2023['Consommation_Diff'], predictions_series)

# Affichage des métriques
print(f'RMSE: {rmse}')
print(f'R²: {r2}')

# Visualisation des résultats avec zoom sur la période de test
plt.figure(figsize=(15, 7))
plt.plot(serie_form['Consommation_Diff'], label='Formation')
plt.plot(serie_2023['Consommation_Diff'], label='Réel', color='orange')
plt.plot(predictions_series, label='Prédictions', color='green')
plt.title('Prédictions SARIMAX avec Variables Exogènes vs Valeurs Réelles (Période de Test)')
plt.xlabel('Date')
plt.ylabel('Consommation Différence')
plt.legend()

# Limiter l'axe des x à la période de test
plt.xlim(serie_2023.index[0], serie_2023.index[-1])

plt.show()
# Out:
#                                       SARIMAX Results
# ...
# Dep. Variable:                    Consommation_Diff   No. Observations:                 1088
# Model:             SARIMAX(6, 0, 5)x(2, 1, [1], 12)   Log Likelihood               -9875.211
# Date:                              Thu, 11 Jan 2024   AIC                          19784.421
# Time:                                      23:14:19   BIC                          19868.618
# Sample:                                  01-09-2020   HQIC                         19816.352
#                                        - 12-31-2022
# Covariance Type:                                opg
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Température moyenne (°C)   -35.5111     13.840     -2.566      0.010     -62.638      -8.384
# ...

# %% [markdown]
# <div style="font-family: Arial, sans-serif; color: #333; font-size: 14px;">
#     <h2 style="color: #75DFC1;">Analyse du Modèle SARIMAX Final</h2>
#     <p>
#         Le modèle SARIMAX final avec un ordre (6,0,5) et une saisonnalité (2,1,[1],12) a intégré la température moyenne et les jours fériés comme variables exogènes, révélant leur impact significatif sur la consommation d'énergie. Le RMSE de 2533.82 et le R² de 0.3456, bien que supérieurs aux modèles précédents, indiquent que le modèle capte une portion considérable de la variance dans les données.
#     </p>
#     <p>
#         L'ajustement des composantes AR et MA démontre une corrélation temporelle significative, tandis que les coefficients des variables exogènes soulignent leur influence directe. Le fait que la matrice de covariance soit presque singulière suggère que le modèle pourrait être amélioré pour renforcer la stabilité des estimations des paramètres.
#     </p>
#
# </div>

# %% [markdown]
# <div style="font-family: Arial, sans-serif; color: #333; font-size: 14px;">
#     <h2 style="color: #75DFC1;">Synthèse du Modèle SARIMAX Retenu</h2>
#     <p>
#         Le modèle SARIMAX retenu avec les paramètres (6, 0, 5) pour la partie ARIMA et (2, 1, 1, 12) pour la composante saisonnière indique une capacité à capturer les dynamiques complexes et saisonnières de la consommation énergétique. Bien que le RMSE de 2533.81 et le R² de 0.3456 montrent une amélioration par rapport aux modèles précédents, nous sommes à la recherche d'une performance encore meilleure.
#     </p>
#     <p>
#         En poursuivant notre analyse, nous allons maintenant explorer des modèles d'apprentissage automatique comme XGBoost et LSTM pour leur potentiel à modéliser des relations non linéaires et à améliorer la précision des prédictions.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:4px;border-color:#4CAF50">
# <center><h1> Modèles d'Apprentissage Automatique </h1></center>
# <hr style="border-width:4px;border-color:#4CAF50">

# %% [markdown]
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Amélioration de l'Ingénierie des Caractéristiques pour la Modélisation Énergétiqu
# </span>
# <p style="font-size: 16px;">
#     L'objectif ici est de créer des variables rétardées (lag features) à partir de la consommation énergétique. Ces variables permettront au modèle d'apprendre des tendances et des motifs basés sur les valeurs passées, contribuant à une meilleure précision des prévisions.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Séparation en Ensembles de Formation et de Test
# </span>
# <p style="font-size: 16px;">
#     La division de la base de données en ensembles d'entraînement et de test est cruciale pour évaluer la performance du modèle. Elle garantit que le modèle est entraîné et testé sur des données distinctes, fournissant ainsi une évaluation réaliste de sa capacité à généraliser.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Entraînement du Modèle XGBoost
# </span>
# <p style="font-size: 16px;">
#     L'utilisation de XGBoost, un algorithme puissant et efficace pour les tâches de régression, permet de tirer parti de ses capacités avancées en matière de gestion des données manquantes et de réglage des paramètres. Il offre également une vitesse et une performance améliorées.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Utilisation de la Métrique RMSE
# </span>
# <p style="font-size: 16px;">
#     L'erreur quadratique moyenne (RMSE) est utilisée comme indicateur pour mesurer la précision des prédictions du modèle. Cette métrique permet d'évaluer l'écart entre les valeurs prédites et les valeurs réelles, offrant un aperçu clair de la performance du modèle.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Prévision avec le Modèle
# </span>
# <p style="font-size: 16px;">
#     Après l'entraînement, le modèle est utilisé pour faire des prévisions sur l'ensemble de test. Cela permet de comparer les valeurs prédites avec les données réelles et d'évaluer l'efficacité du modèle dans des conditions réelles.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">
#     Entraînement d'un Modèle LSTM
# </span>
# <p style="font-size: 16px;">
#     En plus de XGBoost, un modèle LSTM (Long Short-Term Memory) sera également entraîné. Les LSTM sont particulièrement efficaces pour les séries temporelles, car ils peuvent apprendre et retenir des dépendances à long terme dans les données.
# </p>

# %%
Conso_Energie_Diff_Clean = Conso_Energie_Diff_Clean.drop(columns=['Pic journalier consommation (MW)', 'Consommation à température normale (MW)', 'Consommation Brut (MW)', 'Weekday Name'])
Conso_Energie_Diff_Clean.columns
# Out:
# Index(['Température moyenne (°C)', 'Température référence (°C)', 'IsHoliday',
#        'Year', 'Month', 'Day', 'Weekday', 'WeekOfYear', 'DayOfWeek',
#        'IsWeekend', 'Consommation_Diff'],
#       dtype='object')

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h1 style="background-color: #F0E68C; padding: 5px; width: auto; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0,0,0,0.15), 0 4px 8px 0 rgba(0,0,0,0.15);">Amélioration de l'Ingénierie des Caractéristiques pour la Modélisation Énergétique</h1>
#
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Utilité des Caractéristiques Retardées (Lags)</span>
# <p style="font-size: 16px;">
#             L'intégration de lags dans notre modèle permet d'encapsuler les effets de la consommation d'énergie des jours précédents sur les jours suivants. Ces lags agissent comme des échos temporels qui capturent non seulement les réponses directes à des stimuli comme les changements de température et les événements saisonniers, mais aussi les comportements différés tels que les ajustements d'usage après des jours fériés ou des périodes de pic.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Intégration de Fenêtres Glissantes</span>
# <p style="font-size: 16px;">
#     Les fenêtres glissantes fournissent une moyenne et un écart-type sur une période donnée, offrant ainsi une perspective lissée de la consommation. Cette approche permet de détecter les tendances globales et la variabilité dans la série temporelle, en réduisant l'impact des fluctuations journalières et en mettant en évidence les tendances sur une semaine.
# </p>
#
# <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Décomposition de la Série Temporelle</span>
# <p style="font-size: 16px;">
#     La décomposition de la série temporelle en composantes de tendance, saisonnière et résiduelle offre une vue détaillée de la consommation. Cette méthode permet de séparer les effets à long terme (tendance), les cycles répétitifs (saisonnière) et les variations inexpliquées (résiduelle). Cela fournit des insights précieux pour la modélisation et aide à mieux comprendre les facteurs sous-jacents de la consommation.
# </p>
#
#    <span style="font-size: 20px; margin-bottom: 5px; color: #4CAF50; font-weight: bold;">Introduction des Délais dans les Résidus</span>
# <p style="font-size: 16px;">
#         En prenant en compte les résidus, ou les parties de la consommation qui ne sont pas expliquées par la tendance ou la saison, on peut détecter des changements soudains ou des événements imprévus, permettant au modèle de s'adapter rapidement.
#  </p>
# <p style="font-size: 16px;">
#     Ensemble, ces caractéristiques avancées enrichissent notre modèle prédictif en offrant une compréhension plus nuancée et détaillée de la consommation énergétique. Elles permettent d'améliorer la précision des prévisions et de fournir des insights plus profonds sur la dynamique de la consommation d'énergie.
# </p>
# <p style="font-size: 16px;">
#     Toutefois, il est essentiel de gérer la complexité accrue pour éviter de surinterpréter les résultats ou d'introduire des erreurs telles que la multicollinéarité.
# </p>

# %%
# Créer des lag features
for lag in range(1, 5):
    Conso_Energie_Diff_Clean[f'Consommation_Diff_lag{lag}'] = Conso_Energie_Diff_Clean['Consommation_Diff'].shift(lag)
    
    # Créer des rolling window features
window = 7  # Fenêtre d'une semaine
Conso_Energie_Diff_Clean['Rolling_Mean'] = Conso_Energie_Diff_Clean['Consommation_Diff'].rolling(window).mean()
Conso_Energie_Diff_Clean['Rolling_Std'] = Conso_Energie_Diff_Clean['Consommation_Diff'].rolling(window).std()

# Décomposition de la série temporelle
decomposition = seasonal_decompose(Conso_Energie_Diff_Clean['Consommation_Diff'], model='additive')
Conso_Energie_Diff_Clean['Trend'] = decomposition.trend
Conso_Energie_Diff_Clean['Seasonal'] = decomposition.seasonal
Conso_Energie_Diff_Clean['Residual'] = decomposition.resid


# Créer des lag Residual
for lag in range(1, 5):
    Conso_Energie_Diff_Clean[f'Residual{lag}'] = Conso_Energie_Diff_Clean['Residual'].shift(lag)
    

# Supprimer les NaN créés par les lags et la fenêtre glissante
Conso_Energie_Diff_Clean = Conso_Energie_Diff_Clean.dropna()

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Division des données en ensembles d'entraînement et de test</h1>

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Séparation des Données et Préparation pour la Modélisation</h3>
#     <p>
#         Pour construire et tester notre modèle de prévision, nous commençons par séparer nos données en deux ensembles : un ensemble d'entraînement (train) et un ensemble de test (test). La date du 31 décembre 2022 sert de point de séparation, avec toutes les données antérieures à cette date incluses dans l'ensemble d'entraînement et les données postérieures dans l'ensemble de test. Cette méthode nous permet d'entraîner le modèle sur des données historiques et de le tester sur des données récentes pour évaluer sa précision.
#     </p>
#     <p>
#         Ensuite, nous convertissons les dates de notre ensemble de données en une forme numérique, ce qui est essentiel pour l'analyse de séries temporelles. Cette conversion transforme les dates en un nombre de jours écoulés depuis la première date de notre ensemble de données, offrant une mesure temporelle continue pour le modèle.
#     </p>
#     <p>
#         Après cela, nous séparons les variables indépendantes (X) et la variable dépendante (y). La variable indépendante X comprend toutes les caractéristiques sauf 'Consommation_Diff', qui est notre variable cible (y) que nous cherchons à prédire. Nous procédons de la même manière pour les ensembles d'entraînement et de test.
#     </p>
#     <p>
#         Pour finir, nous vérifions les dimensions de nos ensembles de données (train et test) pour nous assurer que la séparation a été effectuée correctement. Cette étape est cruciale pour valider la structure de nos données avant de passer à l'étape de modélisation.
#     </p>
# </div>

# %%
# Assumant que Conso_Energie_Diff_Clean est votre DataFrame

# Définir la date de séparation pour séparer les données en ensembles d'entraînement et de test
date_separation = '2022-12-31'

# Séparation en ensembles de formation et de test
train = Conso_Energie_Diff_Clean[Conso_Energie_Diff_Clean.index <= pd.to_datetime(date_separation)]
test = Conso_Energie_Diff_Clean[Conso_Energie_Diff_Clean.index > pd.to_datetime(date_separation)]

# Convertir les index de date en représentation numérique pour l'entraînement du modèle
train['date_numeric'] = (train.index - train.index.min()).days
test['date_numeric'] = (test.index - train.index.min()).days



# Sélection de vos variables indépendantes (X) et dépendante (y)
X_train = train.drop('Consommation_Diff', axis=1)
y_train = train['Consommation_Diff']
X_test = test.drop('Consommation_Diff', axis=1)
y_test = test['Consommation_Diff']

# Afficher les premières lignes des ensembles de formation et de test pour vérification

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1088, 24)
# (1088,)
# (331, 24)
# (331,)

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">XGBoost</h1>

# %%
import xgboost as xgb
# Créer une instance du modèle XGBoost
model = xgb.XGBRegressor(enable_categorical=True)
# Entraîner le modèle
model.fit(X_train, y_train)

# Faire des prédictions sur l'ensemble de test
test['prediction'] = model.predict(X_test)

# Évaluer le modèle en utilisant RMSE
rmse = mean_squared_error(y_test, test['prediction'], squared=False)
print("Root Mean Squared Error (RMSE):", rmse)

# Visualiser les résultats réels par rapport aux prédictions
fig, ax = plt.subplots(figsize=(15, 5))
test[['Consommation_Diff']].plot(ax=ax, label='Consommation réelle')
test['prediction'].plot(ax=ax, label='Prédiction', linestyle='--')
ax.legend()
plt.title('Comparaison de la consommation réelle et prédite')
plt.show()
# Out:
# Root Mean Squared Error (RMSE): 457.04647965544933

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h3 style="color: #75DFC1;">Interprétation des Prévisions de Consommation Énergétique par XGBoost</h3>
#     <p>
#         L'examen du graphique de comparaison des prévisions du modèle XGBoost avec les valeurs réelles pour l'année 2023 montre une certaine conformité des tendances. Bien que les prévisions ne correspondent pas parfaitement aux valeurs réelles, elles semblent suivre la même direction générale, avec des pics et des creux en concordance.
#     </p>
#     <p>
#         L'erreur quadratique moyenne (RMSE) de 457.046 est une mesure de l'écart entre les prédictions et les valeurs réelles. Plus le RMSE est faible, meilleure est la précision du modèle. Dans ce contexte, un RMSE de 457.046 indique une précision acceptable du modèle, mais il y a toujours de la place pour l'optimisation.
#     </p>
#     <p>
#         Les prédictions semblent capter l'ampleur des fluctuations de la consommation énergétique, mais il peut y avoir des moments spécifiques où le modèle ne saisit pas entièrement la variabilité ou les événements inhabituels. Une analyse plus détaillée des résidus et des erreurs pourrait révéler des informations supplémentaires sur les points forts et les faiblesses du modèle.
#     </p>
#     <p>
#         Pour améliorer la performance du modèle, une exploration plus approfondie des hyperparamètres, l'ajout de variables explicatives supplémentaires, ou l'application de techniques de feature engineering pourrait être envisagée. L'objectif est d'affiner le modèle pour qu'il puisse mieux comprendre et prédire les nuances de la consommation énergétique.
#     </p>
# </div>

# %%
# Utilisation de plot_importance pour visualiser les caractéristiques importantes
xgb.plot_importance(model, max_num_features=15, importance_type='gain')
plt.title("Importance des Caractéristiques (XGBoost)")
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h3 style="color: #75DFC1;">Analyse de l'Importance des Caractéristiques avec XGBoost</h3>
#     <p>
#         L'analyse de l'importance des caractéristiques via XGBoost a révélé des insights clés sur les facteurs influençant la consommation énergétique. Les caractéristiques avec les scores F les plus élevés sont considérées comme ayant le plus d'impact sur la prédiction de notre modèle.
#     </p>
#     <ul>
#         <li><strong>Résiduel</strong> et <strong>Saisonnier</strong> : Ces caractéristiques, dérivées de la décomposition de la série temporelle, montrent une influence prédominante, reflétant les effets sous-jacents et les cycles saisonniers sur la consommation d'énergie.</li>
#         <li><strong>IsHoliday</strong> : Cette variable binaire, qui indique les jours fériés, joue également un rôle significatif, mettant en évidence les variations de consommation lors des jours non ouvrables.</li>
#         <li><strong>Consommation_Diff_lag1</strong> et autres <strong>lags</strong> : L'importance de ces lags souligne la pertinence des valeurs passées et de la mémoire à court terme dans la prédiction des tendances de consommation future.</li>
#         <li><strong>Weekday</strong>, <strong>Trend</strong>, <strong>Year</strong> et <strong>WeekOfYear</strong> : Ces caractéristiques temporelles montrent que la consommation est fortement influencée par le temps, avec des variations selon le jour de la semaine, les tendances générales et les périodes de l'année.</li>
#     </ul>
#     <p>
#         Ces résultats permettent de mieux comprendre les dynamiques de la consommation énergétique et d'améliorer la précision de nos prévisions. Cependant, il convient d'aborder ces caractéristiques avec prudence pour éviter le surajustement et garantir que le modèle reste généralisable.
#     </p>
# </div>

# %%
# Instancier XGBRegressor
xgbr = xgb.XGBRegressor(seed=20)

# Définir la grille des hyperparamètres à tester
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 500, 1000],
    'colsample_bytree': [0.3, 0.7],
    'subsample': [0.7, 1],
    'gamma': [0, 0.1, 0.2]
}

# Créer la fonction de score basée sur RMSE
rmse_scorer = make_scorer(mean_squared_error, greater_is_better=False)

# Configurer la recherche sur grille avec validation croisée
grid_search = GridSearchCV(
    estimator=xgbr,
    param_grid=param_grid,
    scoring=rmse_scorer,
    cv=5,
    verbose=1,
    n_jobs=-1  # Utiliser tous les processeurs
)

# Exécuter la recherche sur grille
grid_search.fit(X_train, y_train)

# Afficher les meilleurs paramètres
print(f"Meilleurs paramètres: {grid_search.best_params_}")

# Utiliser le meilleur modèle pour faire des prédictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Calculer et afficher le RMSE du meilleur modèle
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f"RMSE du meilleur modèle: {rmse}")
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Meilleurs paramètres: {'colsample_bytree': 0.7, 'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000, 'subsample': 1}
# RMSE du meilleur modèle: 292.0922031654923

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculer et afficher le RMSE du meilleur modèle
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f"RMSE du meilleur modèle: {rmse}")
# Supposons que 'test' est votre DataFrame et 'y_pred' est votre tableau de prédictions
test['Prediction'] = y_pred  # Ajoutez les prédictions au DataFrame de test

# Visualiser les résultats réels par rapport aux prédictions
fig, ax = plt.subplots(figsize=(15, 5))
test[['Consommation_Diff']].plot(ax=ax, label='Consommation réelle')
test['Prediction'].plot(ax=ax, label='Prédiction', linestyle='--')
ax.legend()
plt.title('Comparaison de la consommation réelle et prédite')
plt.show()
# Out:
# RMSE du meilleur modèle: 292.0922031654923

# %%
# Utilisation de plot_importance pour visualiser les caractéristiques importantes
xgb.plot_importance(model, max_num_features=15, importance_type='gain')
plt.title("Importance des Caractéristiques (XGBoost)")
plt.show()

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: #75DFC1;">Interprétation de la Performance du Modèle Optimisé</h3>
#     <p>
#         Le modèle optimisé a produit une erreur quadratique moyenne (RMSE) de 292, une nette amélioration par rapport à la version précédente du modèle. Cette amélioration significative indique que le modèle est désormais capable de prédire la consommation d'énergie avec une précision accrue, réduisant l'écart entre les valeurs prévues et les valeurs réelles.
#     </p>
#     <p>
#         L'ajustement des hyperparamètres a joué un rôle clé dans cette amélioration. Les paramètres sélectionnés, comme un 'colsample_bytree' de 0.7 et un 'gamma' de 0.1, ont contribué à un modèle plus robuste et moins sujet au surapprentissage. Un 'learning_rate' de 0.1 associé à une 'max_depth' de 3 et 1000 estimateurs a permis d'obtenir des prédictions plus stables et fiables.
#     </p>
#     <p>
#         Les caractéristiques importantes identifiées par le modèle révèlent les variables les plus influentes dans la prédiction de la consommation d'énergie. Par exemple, les variables 'Seasonal' et 'Residual' ont montré une forte influence, indiquant l'importance des cycles saisonniers et des composants résiduels dans la consommation énergétique. La présence de jours fériés ('IsHoliday') a également été reconnue comme un facteur pertinent, affectant la consommation d'énergie de manière significative.
#     </p>
#     <p>
#         En conclusion, le modèle optimisé avec les hyperparamètres ajustés et une sélection rigoureuse des caractéristiques offre une prédiction très précise. Cela souligne l'efficacité de l'approche de réglage des hyperparamètres et du feature engineering dans l'amélioration des modèles de machine learning.
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #ffff99; padding: 5px; width: 600px; font-size: 30px; text-align: center; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.15), 0 4px 8px 0 rgba(0, 0, 0, 0.15);">Modèle LSTM</h1>

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Assuming X_train and X_test are already loaded and are Pandas DataFrames

# Enregistrez l'index de y_test avant toute manipulation
test_dates = y_test.index

# Normalizing input features
scaler_x = MinMaxScaler(feature_range=(0, 1))
X_train_scaled = scaler_x.fit_transform(X_train)
X_test_scaled = scaler_x.transform(X_test)

# Normalizing output feature
scaler_y = MinMaxScaler(feature_range=(0, 1))
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))

# Reshaping input data for LSTM [samples, time steps, features]
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# Define the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Fit the model to the training data
model.fit(
    X_train_reshaped,
    y_train_scaled,
    epochs=100,
    batch_size=32,
    validation_data=(X_test_reshaped, y_test_scaled),
    verbose=1
)

# Predicting on the test set
y_test_pred_scaled = model.predict(X_test_reshaped)

# Inverse transforming the scaled prediction to actual values
y_test_pred = scaler_y.inverse_transform(y_test_pred_scaled)

# Create a DataFrame for the predictions using the original test dates index
y_test_pred_df = pd.DataFrame(y_test_pred, index=test_dates, columns=['Predictions'])

# Calculating RMSE for the test set
# Calculating RMSE and other metrics for both training and test set
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred_df['Predictions']))

print(f"Test RMSE: {test_rmse}")
# Plotting the predictions alongside the actual values
plt.figure(figsize=(15, 7))
plt.plot(y_test, label='Actual values', color='blue')
plt.plot(y_test_pred_df['Predictions'], label='LSTM predicted values', color='red', alpha=0.7)
plt.title("Energy Consumption Prediction using LSTM")
plt.xlabel("Date")
plt.ylabel("Energy Consumption")
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 34/34 [==============================] - 4s 27ms/step - loss: 0.0540 - val_loss: 0.0089
# Epoch 2/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 3/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0047
# Epoch 4/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 5/100
# 34/34 [==============================] - 1s 18ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 6/100
# 34/34 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 7/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 8/100
# 34/34 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 9/100
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 10/100
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <h3 style="color: #75DFC1;">Conclusion Générale du Projet</h3>
#     <p>
#         Le parcours à travers les modèles de prédiction a été riche d'enseignements. Nous avons constaté une amélioration notable avec le modèle XGBoost optimisé, affichant un RMSE de 292. Le modèle LSTM, avec un MSE de 290, a également montré un fort potentiel pour la prédiction précise des tendances de consommation énergétique.
#     </p>
#     <p>
#         La mise en œuvre d'un système de surveillance continue, actualisant les prévisions au fur et à mesure de la réception de nouvelles données, se présente comme une étape incontournable. Cela assurera une réponse agile aux fluctuations de la consommation énergétique et aux changements environnementaux.
#     </p>
#     <p>
#         Enfin, notre quête d'excellence ne s'arrête pas ici. Nous envisageons d'explorer davantage les modèles d'apprentissage automatique pour saisir les nuances complexes de la consommation d'énergie. C'est une étape cruciale vers une gestion énergétique plus efficiente et durable.
#     </p>
# </div>
